# %% [markdown]
# # Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ## Задача 1
#
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.
#
# ### Примеры работы программы:
# 1. phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
#    phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# **Результат**: Фраза 1 длиннее фразы 2
#
# 2. phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#    phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# **Результат**: Фраза 2 длиннее фразы 1
#
# 3. phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
#    phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
#
# **Результат**: Фразы равной длины

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else: 
    print('Фразы равной длины')
# Out:
# Фраза 1 длиннее фразы 2

# %% [markdown]
# ## Задача 2
#
# Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# ### Пример работы программы:
#
# 1. year = 2020
#
# **Результат**: Високосный год
#
# 2. year = 2019
#
# **Результат**: Обычный год

# %%
year = 2026

if year % 4 == 0:
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Обычный год

# %% [markdown]
# ## Задача 3
#
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# ### Пример работы программы:
# 1. Введите день:30
# Введите месяц: Август
#
# **Результат**:
# Ваш знак зодиака: Дева
#
# 2. Введите день: 29
# Введите месяц: Октябрь
#
# **Результат**: Ваш знак зодиака: Скорпион
#
# ![image.png](attachment:3ba48a47-809b-4fb0-bf63-e2a6a61ca546.png)

# %%
day = int(input("Введите день: "))
month = input("Введите месяц: ")
month = month.lower()

if month == "март":
    if day <= 20:
        result = 'Рыбы'
    else:
        result = 'Овен'
        
elif month == "апрель":
    if day <= 20:
        result = 'Овен'
    else:
        result = 'Телец'
        
elif month == "май":
    if day <= 20:
        result = 'Телец'
    else:
        result = 'Близнецы'
        
elif month == "июнь":
    if day <= 21:
        result = 'Близнецы'
    else:
        result = 'Рак'
        
elif month == "июль":
    if day <= 22:
        result = 'Рак'
    else:
        result = 'Лев'
        
elif month == "август":
    if day <= 23:
        result = 'Лев'
    else:
        result = 'Дева'
        
elif month == "сентябрь":
    if day <= 23:
        result = 'Дева'
    else:
        result = 'Весы'
        
elif month == "октябрь":
    if day <= 23:
        result = 'Весы'
    else:
        result = 'Скорпион'
        
elif month == "ноябрь":
    if day <= 22:
        result = 'Скорпион'
    else:
        result = 'Стрелец'
        
elif month == "декабрь":
    if day <= 21:
        result = 'Стрелец'
    else:
        result = 'Козерог'
        
elif month == "январь":
    if day <= 20:
        result = 'Козерог'
    else:
        result = 'Водолей'
        
elif month == "февраль":
    if day <= 20:
        result = 'Водолей'
    else:
        result = 'Рыбы'
else:
    result = 'ошибка в названии месяца'

if day <= 0 or day > 31: 
    result = """hyrax 
      ╭───╮
    </     \>
    │ ●   ● │
    │   ▼   │
    │   ⌄   │
     \\     /
      ╰───╯
       U U
"""

print("Ваш знак зодиака:", result)
# Out:
# Введите день:  24
# Введите месяц:  Апрель
# Ваш знак зодиака: Телец

# %% [markdown]
# ## Задача 4
#
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
#
# * если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
# * если хотя бы одно из измерений больше 2 метров, то выводите "Упаковка для лыж";
# * если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# * во всех остальных случаях выводите "Коробка №3".
#
# ### Пример работы программы:
#
# 1. width = 15
# length = 55
# height = 15
#
# **Результат**: Коробка №3
#
# 2. width = 45
# length = 205
# height = 45
#
# **Результат**: Упаковка для лыж

# %%
width = int(input("Введите ширину (см): "))
length = int(input("Введите длину (см): "))
height = int(input("Введите высоту (см): "))

if width <= 15 and length <= 15 and height <= 15:
    print("Коробка №1")
elif width > 200 or length > 200 or height > 200:
    print("Упаковка для лыж")
elif width < 50 or length < 50 or height < 50:
    print("Коробка №2")
else:
    print("Коробка №3")
# Out:
# Введите ширину (см):  5
# Введите длину (см):  5
# Введите высоту (см):  16
# Коробка №2
